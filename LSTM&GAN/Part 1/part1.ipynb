# %%
# %matplotlib inline
# %run train.py --input_length 5
# Out:
# LSTM is WORKING...
# Done training.

# %%
# %matplotlib inline
# %run vanilla_train.py --input_length 5
# Out:
# Vanilla RNN is WORKING...
# Done training.

# %%
# %matplotlib inline
# %run train.py --input_length 30
# Out:
# LSTM is WORKING...
# Done training.

# %%
# %matplotlib inline
# %run vanilla_train.py --input_length 30
