# %%
from IPython.display import Image as img
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
print('At the very beginning of the training.')
print('Respectively at: 0, 1000, 2000, 3000, 5000, 7500, 9000, 11500, 13500 ')

path = "./task2_images/0.png"
path1 = "./task2_images/1000.png"
path2 = "./task2_images/2000.png"
path3 = "./task2_images/3000.png"
path4 = "./task2_images/5000.png"
path5 = "./task2_images/7500.png"
path6 = "./task2_images/9000.png"
path7 = "./task2_images/11500.png"
path8 = "./task2_images/13500.png"
display(img(path))
display(img(path1))
display(img(path2))
display(img(path3))
display(img(path4))
display(img(path5))
display(img(path6))
display(img(path7))
display(img(path8))
# Out:
# At the very beginning of the training.
# Respectively at: 0, 1000, 2000, 3000, 5000, 7500, 9000, 11500, 13500,

# %%
print('During the process of the training.')
print('Respectively at: 16000, 20000, 32000, 41000, 50000, 60000, 79500, 80000, 99500 ')

path = "./task2_images/16000.png"
path1 = "./task2_images/20000.png"
path2 = "./task2_images/32000.png"
path3 = "./task2_images/41000.png"
path4 = "./task2_images/50000.png"
path5 = "./task2_images/60000.png"
path6 = "./task2_images/79500.png"
path7 = "./task2_images/80000.png"
path8 = "./task2_images/99500.png"
display(img(path))
display(img(path1))
display(img(path2))
display(img(path3))
display(img(path4))
display(img(path5))
display(img(path6))
display(img(path7))
display(img(path8))
# Out:
# During the process of the training.
# Respectively at: 16000, 20000, 32000, 41000, 50000, 60000, 79500, 80000, 99500

# %%
print('At the ending of the training.')
print('Respectively at: 120000, 130000, 140000, 150000, 160000, 170000, 185000, 187000 ')

path = "./task2_images/120000.png"
path1 = "./task2_images/130000.png"
path2 = "./task2_images/140000.png"
path3 = "./task2_images/150000.png"
path4 = "./task2_images/160000.png"
path5 = "./task2_images/170000.png"
path6 = "./task2_images/185000.png"
path7 = "./task2_images/187000.png"
display(img(path))
display(img(path1))
display(img(path2))
display(img(path3))
display(img(path4))
display(img(path5))
display(img(path6))
display(img(path7))
# Out:
# At the ending of the training.
# Respectively at: 120000, 130000, 140000, 150000, 160000, 170000, 185000, 187000
